# %% [markdown]
# ## Logistic Regression Practice - Part I (Data Exploratory Analysis)

# %% [markdown]
#  * Working with the Kaggle.com Titanic Dataset

# %% [markdown]
# ### Step 1 - Imports

# %%
# Import data analysis modules

import numpy as np
import pandas as pd

# %%
# Import visualization modules

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Step 2 - Read in Dataset File

# %%
# Use pandas to read in csv file

train = pd.read_csv('titanic_train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Step 3 - Conduct Data Analysis

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Use the .isnull() method to locate missing data
missing_values = train.isnull()
missing_values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
# Use seaborn to conduct heatmap to identify missing data
# data -> argument refers to the data to creat heatmap
# yticklabels -> argument avoids plotting the column names
# cbar -> argument identifies if a colorbar is required or not
# cmap -> argument identifies the color of the heatmap

sns.heatmap(data = missing_values, yticklabels=False, cbar=False, cmap='viridis')

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Use the countplot() method to identify ratio of who survived vs. not
# (Tip) very helpful to get a visualization of the target label
# x -> argument referes to column of interest
# data -> argument refers to dataset

sns.countplot(x='Survived', data=train)

# %%
# Use the countplot() method to identify ratio of who survived vs. not
# x -> argument referes to column of interest
# data -> argument refers to dataset
# hue -> allows another level to subdivide data
# palette -> argument refers to plot color

sns.countplot(x='Survived', data=train, hue='Sex', palette='RdBu_r')

# %%
# Use the countplot() method to identify ratio of who survived vs. not with interest in Passenger class
# x -> argument referes to column of interest
# data -> argument refers to dataset
# hue -> allows another level to subdivide data
# palette -> argument refers to plot color

sns.countplot(x='Survived', data=train, hue='Pclass')

# %%
# Use the .distplot() method to identify distribution of ages

sns.distplot(train['Age'].dropna(), kde=True, bins=30)

# %%
# Use pandas to create plot

train['Age'].plot.hist(bins=25)

# %%
# Review the Features in the dataset

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# Use the .countplot() method to investigate the Sib Feature

sns.countplot(x='SibSp',data = train)

# %%
# Use the .distplot() method to investigate the distribution of what people paid

train['Fare'].plot.hist(bins=50, figsize=(10,4))

# %% [markdown]
# ## Logistic Regression Practice - Part II (Data Cleaning)

# %% [markdown]
# #### Step 1 - Identify the variation of ages by classes

# %%
# Identify outliers in the data with the .boxplot() method

plt.figure(figsize=(10,7))
sns.boxplot(x='Pclass', y='Age', data = train)

# %% [markdown]
# #### Step 2 - Create Function to fill in missing values

# %%
# Create function to impute the age value if it is null

def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    
    if pd.isnull(Age):
        
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
# Apply function to impute the age for missing values
# The age column is at position 0
# The pclass column is at position 1
# axis -> argument refers to columns instead of rows to apply the impute_age function

train['Age'] = train[['Age', 'Pclass']].apply(impute_age, axis=1)

# %% [markdown]
# #### Step 3 - Visualize the updated dataset with the imputed age values

# %%
# Create heatmap to display updated age values
# yticklabels -> argument removes the column labels
# cbar -> argument removes the color bar
# cmap -> argument defines the color of the map

sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# #### Step 4 - Drop columns and rows that have too much missing data

# %%
# Use the .drop() method to remove columns that have too much missing data

# axis -> argument referes to either row(0) or column(1) to specify
# inplace -> argument permanently removes the column instead of just removing the view

train.drop('Cabin', axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
# Use the .dropna() method to remove rows that contain missing values

train.dropna(inplace=True)

# %% [markdown]
# #### Step 5 - Create Dummy values for categorical data

# %%
# Use the .get_dummies() method to convert categorical data into dummy values
# train['Sex'] refers to the column we want to convert
# drop_first -> argument avoids the multicollinearity problem, which can undermines
# the statistical significance of an independent variable.

sex = pd.get_dummies(train['Sex'], drop_first=True)

# %%
embark = pd.get_dummies(train['Embarked'], drop_first=True)

# %% [markdown]
# #### Step 6 - Create new dataframe with converted categorical data

# %%
# Use  .concat() method to merge the series data into one dataframe


train = pd.concat([train, sex, embark], axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0         0       3  22.0      1      0   7.2500     1  0  1
# 1         1       1  38.0      1      0  71.2833     0  0  0
# 2         1       3  26.0      0      0   7.9250     0  0  1
# 3         1       1  35.0      1      0  53.1000     0  0  1
# 4         0       3  35.0      0      0   8.0500     1  0  1

# %% [markdown]
# #### Step 7 - Remove further categorical columns from dataframe

# %%
# Drop columns with categorical data

train.drop(['Sex','Embarked','Ticket','Name'], axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0            1         0       3  22.0      1      0   7.2500     1  0  1
# 1            2         1       1  38.0      1      0  71.2833     0  0  0
# 2            3         1       3  26.0      0      0   7.9250     0  0  1
# 3            4         1       1  35.0      1      0  53.1000     0  0  1
# 4            5         0       3  35.0      0      0   8.0500     1  0  1

# %%
# Drop columns that are duplicate index

train.drop('PassengerId', axis=1, inplace=True)

# %%
train.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0         0       3  22.0      1      0   7.2500     1  0  1
# 1         1       1  38.0      1      0  71.2833     0  0  0
# 2         1       3  26.0      0      0   7.9250     0  0  1
# 3         1       1  35.0      1      0  53.1000     0  0  1
# 4         0       3  35.0      0      0   8.0500     1  0  1

# %% [markdown]
# ## Logistic Regression Practice - Part III

# %% [markdown]
# #### Step 1 - Split dataset into training and test elements

# %%
# Review column names again

train.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'male', 'Q',
#        'S'],
#       dtype='object')

# %%
# Split data into 'X' features and 'y' target label sets

X = train[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'male', 'Q',
       'S']]
y = train['Survived']

# %% [markdown]
# #### Step 2 - Import sklearn module to split data into training and test sets

# %%
# Import module to split dataset
from sklearn.model_selection import train_test_split

# %%
# Split data set into training and test sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# #### Step 3 - Import sklearn module to train model and make predictions

# %%
# Import module for fitting

from sklearn.linear_model import LogisticRegression

# %%
# Create instance (i.e. object) of LogisticRegression

logmodel = LogisticRegression()

# %%
# Fit the model using the training data

# X_train -> parameter supplies the data features
# y_train -> parameter supplies the target labels

logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Make predictions using the .predict() method with the X_test paramter

predictions = logmodel.predict(X_test)

# %% [markdown]
# #### Step 4 - Conduct Classification Report

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.80      0.91      0.85       163
#           1       0.82      0.65      0.73       104
#
# avg / total       0.81      0.81      0.80       267
