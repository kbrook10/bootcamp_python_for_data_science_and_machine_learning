# %% [markdown]
# ## Seaborn - Grids

# %% [markdown]
# ### Step (1) - Setup

# %%
# import necessary library, configure matplotlib plotting and load in data set
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
iris = sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# ### Step (2) - Explore Dataset

# %%
# Identify the unique values of a column within the dataset
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
# Create Cluster map with .corr() method
imx = iris.corr()
sns.clustermap(imx, cmap='coolwarm')

# %%
# Conduct a pairplot on the data to identify similarities
sns.pairplot(iris, hue='species', diag_kind='kde')

# %% [markdown]
# ### Step (3) - How to configure and use PairGrid to further customize pairplots

# %%
# Use the .PairGrid() method to generate blank plots of the numerical columns within the dataset
g = sns.PairGrid(iris)

# %%
# Use the .map() method to pass in the plot type desired
g.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-4cb01fc88047> in <module>()
#       1 # Use the .map() method to pass in the plot type desired
# ----> 2 g.map(plt.scatter)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/seaborn/axisgrid.py in map(self, func, **kwargs)
#    1294
#    1295                     ax = self.axes[i, j]
# -> 1296                     plt.sca(ax)
#    1297
#    1298                     # Insert the other hue aesthetics if appropriate
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in sca(ax)
#     939             m.canvas.figure.sca(ax)
#     940             return
# --> 941     raise ValueError("Axes instance argument was not found in a figure.")
#     942
#     943
#
# ValueError: Axes instance argument was not found in a figure.
